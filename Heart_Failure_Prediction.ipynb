# %%
import numpy as np #for calculate data
import pandas as pd #for data frame related function use
import matplotlib.pyplot as plt #for creating static, animated, and interactive visualizations
from sklearn import preprocessing #change raw feature vectors into a representation that is more suitable for the downstream estimators
from sklearn.preprocessing import StandardScaler #helps to get standardized distribution, with a zero mean and standard deviation of one (unit variance)
from sklearn.model_selection import train_test_split #Split arrays or matrices into random train and test subsets.
import seaborn as sns #for making statistical graphics
from keras.layers import Dense, BatchNormalization, Dropout, LSTM #
from keras.models import Sequential #for a plain stack of layers where each layer has exactly one input tensor and one output tensor.
from tensorflow.keras.utils import to_categorical #plot categorical data matplotlib
from keras import callbacks #to customize the behavior of a Keras model during training, evaluation, or inference
from sklearn.metrics import precision_score, recall_score, confusion_matrix, classification_report, accuracy_score, f1_score

# %%
#loading data
data = pd.read_csv("dataset/heart_failure_clinical_records_dataset.csv")
data.head() #show first 5 rows from the data
# Out:
#     age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0  75.0        0                       582         0                 20
# 1  55.0        0                      7861         0                 38
# 2  65.0        0                       146         0                 20
# 3  50.0        1                       111         0                 20
# 4  65.0        1                       160         1                 20
#
#    high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# 0                    1  265000.00               1.9           130    1
# 1                    0  263358.03               1.1           136    1
# 2                    0  162000.00               1.3           129    1
# 3                    0  210000.00               1.9           137    1
# 4                    0  327000.00               2.7           116    0
#
#    smoking  time  DEATH_EVENT
# 0        0     4            1
# 1        0     6            1
# 2        1     7            1
# 3        0     7            1
# 4        0     8            1

# %%
data.info() #info about all the feature present in the dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 299 entries, 0 to 298
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   age                       299 non-null    float64
#  1   anaemia                   299 non-null    int64
#  2   creatinine_phosphokinase  299 non-null    int64
#  3   diabetes                  299 non-null    int64
#  4   ejection_fraction         299 non-null    int64
#  5   high_blood_pressure       299 non-null    int64
#  6   platelets                 299 non-null    float64
#  7   serum_creatinine          299 non-null    float64
#  8   serum_sodium              299 non-null    int64
#  9   sex                       299 non-null    int64
#  10  smoking                   299 non-null    int64
#  11  time                      299 non-null    int64
#  12  DEATH_EVENT               299 non-null    int64
# dtypes: float64(3), int64(10)
# memory usage: 30.5 KB

# %%
#first of all let us evaluate the target and find out if our data is imbalanced or not
cols= ["#6daa9f","#774571"] #list of colors for each column
sns.countplot(x= data["DEATH_EVENT"], palette= cols)

# %%
#assigning values to features as X and target as y
X=data.drop(["DEATH_EVENT"],axis=1) #data without DEATH_EVENT columns
y=data["DEATH_EVENT"] #dat of DEATH_EVENT
X
# Out:
#       age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0    75.0        0                       582         0                 20
# 1    55.0        0                      7861         0                 38
# 2    65.0        0                       146         0                 20
# 3    50.0        1                       111         0                 20
# 4    65.0        1                       160         1                 20
# ..    ...      ...                       ...       ...                ...
# 294  62.0        0                        61         1                 38
# 295  55.0        0                      1820         0                 38
# 296  45.0        0                      2060         1                 60
# 297  45.0        0                      2413         0                 38
# 298  50.0        0                       196         0                 45
#
#      high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# 0                      1  265000.00               1.9           130    1
# 1                      0  263358.03               1.1           136    1
# 2                      0  162000.00               1.3           129    1
# 3                      0  210000.00               1.9           137    1
# 4                      0  327000.00               2.7           116    0
# ..                   ...        ...               ...           ...  ...
# 294                    1  155000.00               1.1           143    1
# 295                    0  270000.00               1.2           139    0
# 296                    0  742000.00               0.8           138    0
# 297                    0  140000.00               1.4           140    1
# 298                    0  395000.00               1.6           136    1
#
#      smoking  time
# 0          0     4
# 1          0     6
# 2          1     7
# 3          0     7
# 4          0     8
# ..       ...   ...
# 294        1   270
# 295        0   271
# 296        0   278
# 297        1   280
# 298        1   285
#
# [299 rows x 12 columns]

# %%
#Set up a standard scaler for the features
col_names = list(X.columns) #make a list of the columns or input features
s_scaler = preprocessing.StandardScaler() #create reference of StandardScaler
X_df= s_scaler.fit_transform(X) #scale the all the input feature
# X_df
X_df = pd.DataFrame(X_df, columns=col_names) #convert 2d X_df array to dataframe X_df
X_df.describe().T #describe some statistical calculation about each feature
# Out:
#                           count          mean       std       min       25%  \
# age                       299.0  5.703353e-16  1.001676 -1.754448 -0.828124
# anaemia                   299.0  1.009969e-16  1.001676 -0.871105 -0.871105
# creatinine_phosphokinase  299.0  0.000000e+00  1.001676 -0.576918 -0.480393
# diabetes                  299.0  9.060014e-17  1.001676 -0.847579 -0.847579
# ejection_fraction         299.0 -3.267546e-17  1.001676 -2.038387 -0.684180
# high_blood_pressure       299.0  0.000000e+00  1.001676 -0.735688 -0.735688
# platelets                 299.0  7.723291e-17  1.001676 -2.440155 -0.520870
# serum_creatinine          299.0  1.425838e-16  1.001676 -0.865509 -0.478205
# serum_sodium              299.0 -8.673849e-16  1.001676 -5.363206 -0.595996
# sex                       299.0 -8.911489e-18  1.001676 -1.359272 -1.359272
# smoking                   299.0 -1.188199e-17  1.001676 -0.687682 -0.687682
# time                      299.0 -1.901118e-16  1.001676 -1.629502 -0.739000
#
#                                50%       75%       max
# age                      -0.070223  0.771889  2.877170
# anaemia                  -0.871105  1.147968  1.147968
# creatinine_phosphokinase -0.342574  0.000166  7.514640
# diabetes                 -0.847579  1.179830  1.179830
# ejection_fraction        -0.007077  0.585389  3.547716
# high_blood_pressure      -0.735688  1.359272  1.359272
# platelets                -0.013908  0.411120  6.008180
# serum_creatinine         -0.284552  0.005926  7.752020
# serum_sodium              0.085034  0.766064  2.582144
# sex                       0.735688  0.735688  0.735688
# smoking                  -0.687682  1.454161  1.454161
# time                     -0.196954  0.938759  1.997038

# %%
#spliting test and training sets
X_train, X_test, y_train,y_test = train_test_split(X_df,y,test_size=0.25,random_state=7) #training data has 75%  and test data size of 25% of data

# %%
early_stopping = callbacks.EarlyStopping(
    min_delta=0.001, # minimium amount of change to count as an improvement
    patience=30, # how many epochs to wait before stopping
    restore_best_weights=True)

# Initialising the model type
model = Sequential()

# layers
#input layer
model.add(Dense(units = 16, kernel_initializer = 'uniform', activation = 'relu', input_dim = 12)) #has 16 nodes, input dimention or feature is 12
#hidden layer1
model.add(Dense(units = 8, kernel_initializer = 'uniform', activation = 'relu'))
model.add(Dropout(0.25)) # a technique where randomly selected neurons are ignored during training
#hidden layer2
model.add(Dense(units = 4, kernel_initializer = 'uniform', activation = 'relu'))
model.add(Dropout(0.5))
#output layer
model.add(Dense(units = 1, kernel_initializer = 'uniform', activation = 'sigmoid'))

# %%
# from tensorflow.keras.optimizers import SGD
# Compiling the ANN
#binary_crossentropy for our binary classification
model.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# %%
# Train the ANN
#batch_size --> defines the number of samples that will be propagated through the network

history = model.fit(X_train, y_train, batch_size = 32, epochs = 500,callbacks=[early_stopping], validation_split=0.2)
# Out:
# Epoch 1/500
# 6/6 [==============================] - 1s 45ms/step - loss: 0.6928 - accuracy: 0.6369 - val_loss: 0.6921 - val_accuracy: 0.6667
# Epoch 2/500
# 6/6 [==============================] - 0s 7ms/step - loss: 0.6920 - accuracy: 0.6480 - val_loss: 0.6911 - val_accuracy: 0.6667
# Epoch 3/500
# 6/6 [==============================] - 0s 8ms/step - loss: 0.6910 - accuracy: 0.6480 - val_loss: 0.6902 - val_accuracy: 0.6667
# Epoch 4/500
# 6/6 [==============================] - 0s 8ms/step - loss: 0.6901 - accuracy: 0.6480 - val_loss: 0.6891 - val_accuracy: 0.6667
# Epoch 5/500
# 6/6 [==============================] - 0s 7ms/step - loss: 0.6891 - accuracy: 0.6480 - val_loss: 0.6881 - val_accuracy: 0.6667
# Epoch 6/500
# 6/6 [==============================] - 0s 7ms/step - loss: 0.6884 - accuracy: 0.6480 - val_loss: 0.6869 - val_accuracy: 0.6667
# Epoch 7/500
# 6/6 [==============================] - 0s 6ms/step - loss: 0.6872 - accuracy: 0.6480 - val_loss: 0.6858 - val_accuracy: 0.6667
# Epoch 8/500
# 6/6 [==============================] - 0s 10ms/step - loss: 0.6860 - accuracy: 0.6480 - val_loss: 0.6844 - val_accuracy: 0.6667
# Epoch 9/500
# 6/6 [==============================] - 0s 11ms/step - loss: 0.6845 - accuracy: 0.6480 - val_loss: 0.6828 - val_accuracy: 0.6667
# Epoch 10/500
# 6/6 [==============================] - 0s 11ms/step - loss: 0.6831 - accuracy: 0.6480 - val_loss: 0.6811 - val_accuracy: 0.6667
# Epoch 11/500
# 6/6 [==============================] - 0s 7ms/step - loss: 0.6814 - accuracy: 0.6480 - val_loss: 0.6787 - val_accuracy: 0.6667
# Epoch 12/500
# 6/6 [==============================] - 0s 11ms/step - loss: 0.6798 - accuracy: 0.6480 - val_loss: 0.6758 - val_accuracy: 0.6667
# Epoch 13/500
# 6/6 [==============================] - 0s 7ms/step - loss: 0.6760 - accuracy: 0.6480 - val_loss: 0.6720 - val_accuracy: 0.6667
# Epoch 14/500
# 6/6 [==============================] - 0s 7ms/step - loss: 0.6735 - accuracy: 0.6480 - val_loss: 0.6673 - val_accuracy: 0.6667
# Epoch 15/500
# 6/6 [==============================] - 0s 7ms/step - loss: 0.6691 - accuracy: 0.6480 - val_loss: 0.6612 - val_accuracy: 0.6667
# Epoch 16/500
# 6/6 [==============================] - 0s 7ms/step - loss: 0.6606 - accuracy: 0.6480 - val_loss: 0.6530 - val_accuracy: 0.6667
# Epoch 17/500
# 6/6 [==============================] - 0s 8ms/step - loss: 0.6524 - accuracy: 0.6480 - val_loss: 0.6425 - val_accuracy: 0.6667
# Epoch 18/500
# 6/6 [==============================] - 0s 7ms/step - loss: 0.6408 - accuracy: 0.6480 - val_loss: 0.6305 - val_accuracy: 0.6667
# Epoch 19/500
# 6/6 [==============================] - 0s 6ms/step - loss: 0.6215 - accuracy: 0.6480 - val_loss: 0.6157 - val_accuracy: 0.6667
# Epoch 20/500
# 6/6 [==============================] - 0s 7ms/step - loss: 0.6101 - accuracy: 0.6480 - val_loss: 0.5996 - val_accuracy: 0.6667
# Epoch 21/500
# 6/6 [==============================] - 0s 7ms/step - loss: 0.6028 - accuracy: 0.6480 - val_loss: 0.5840 - val_accuracy: 0.6667
# Epoch 22/500
# 6/6 [==============================] - 0s 7ms/step - loss: 0.5722 - accuracy: 0.6480 - val_loss: 0.5692 - val_accuracy: 0.6667
# Epoch 23/500
# 6/6 [==============================] - 0s 7ms/step - loss: 0.5661 - accuracy: 0.6480 - val_loss: 0.5552 - val_accuracy: 0.6667
# Epoch 24/500
# 6/6 [==============================] - 0s 7ms/step - loss: 0.5340 - accuracy: 0.6480 - val_loss: 0.5454 - val_accuracy: 0.6667
# Epoch 25/500
# 6/6 [==============================] - 0s 8ms/step - loss: 0.5250 - accuracy: 0.6480 - val_loss: 0.5380 - val_accuracy: 0.6667
# Epoch 26/500
# 6/6 [==============================] - 0s 7ms/step - loss: 0.5332 - accuracy: 0.6480 - val_loss: 0.5347 - val_accuracy: 0.6667
# Epoch 27/500
# 6/6 [==============================] - 0s 7ms/step - loss: 0.5049 - accuracy: 0.6480 - val_loss: 0.5323 - val_accuracy: 0.6667
# Epoch 28/500
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4912 - accuracy: 0.6480 - val_loss: 0.5322 - val_accuracy: 0.6667
# Epoch 29/500
# 6/6 [==============================] - 0s 11ms/step - loss: 0.4965 - accuracy: 0.6480 - val_loss: 0.5356 - val_accuracy: 0.6667
# Epoch 30/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.5154 - accuracy: 0.6480 - val_loss: 0.5378 - val_accuracy: 0.6667
# Epoch 31/500
# 6/6 [==============================] - 0s 29ms/step - loss: 0.4948 - accuracy: 0.6480 - val_loss: 0.5413 - val_accuracy: 0.6667
# Epoch 32/500
# 6/6 [==============================] - 0s 10ms/step - loss: 0.5179 - accuracy: 0.6480 - val_loss: 0.5416 - val_accuracy: 0.6667
# Epoch 33/500
# 6/6 [==============================] - 0s 20ms/step - loss: 0.4894 - accuracy: 0.6480 - val_loss: 0.5415 - val_accuracy: 0.6667
# Epoch 34/500
# 6/6 [==============================] - 0s 12ms/step - loss: 0.4916 - accuracy: 0.6480 - val_loss: 0.5437 - val_accuracy: 0.6667
# Epoch 35/500
# 6/6 [==============================] - 0s 13ms/step - loss: 0.5047 - accuracy: 0.6480 - val_loss: 0.5447 - val_accuracy: 0.6667
# Epoch 36/500
# 6/6 [==============================] - 0s 10ms/step - loss: 0.4976 - accuracy: 0.6480 - val_loss: 0.5459 - val_accuracy: 0.6667
# Epoch 37/500
# 6/6 [==============================] - 0s 15ms/step - loss: 0.4818 - accuracy: 0.6480 - val_loss: 0.5481 - val_accuracy: 0.6667
# Epoch 38/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.4765 - accuracy: 0.6480 - val_loss: 0.5492 - val_accuracy: 0.6667
# Epoch 39/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.5071 - accuracy: 0.6480 - val_loss: 0.5477 - val_accuracy: 0.6667
# Epoch 40/500
# 6/6 [==============================] - 0s 12ms/step - loss: 0.4876 - accuracy: 0.6480 - val_loss: 0.5486 - val_accuracy: 0.6667
# Epoch 41/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.4802 - accuracy: 0.6480 - val_loss: 0.5495 - val_accuracy: 0.6667
# Epoch 42/500
# 6/6 [==============================] - 0s 12ms/step - loss: 0.4911 - accuracy: 0.6480 - val_loss: 0.5493 - val_accuracy: 0.6667
# Epoch 43/500
# 6/6 [==============================] - 0s 15ms/step - loss: 0.4570 - accuracy: 0.6480 - val_loss: 0.5502 - val_accuracy: 0.6667
# Epoch 44/500
# 6/6 [==============================] - 0s 20ms/step - loss: 0.4782 - accuracy: 0.6480 - val_loss: 0.5504 - val_accuracy: 0.6667
# Epoch 45/500
# 6/6 [==============================] - 0s 15ms/step - loss: 0.4913 - accuracy: 0.6480 - val_loss: 0.5490 - val_accuracy: 0.6667
# Epoch 46/500
# 6/6 [==============================] - 0s 13ms/step - loss: 0.4602 - accuracy: 0.6480 - val_loss: 0.5505 - val_accuracy: 0.6667
# Epoch 47/500
# 6/6 [==============================] - 0s 13ms/step - loss: 0.4596 - accuracy: 0.6480 - val_loss: 0.5544 - val_accuracy: 0.6667
# Epoch 48/500
# 6/6 [==============================] - 0s 13ms/step - loss: 0.4967 - accuracy: 0.6480 - val_loss: 0.5539 - val_accuracy: 0.6667
# Epoch 49/500
# 6/6 [==============================] - 0s 17ms/step - loss: 0.4859 - accuracy: 0.6480 - val_loss: 0.5544 - val_accuracy: 0.6667
# Epoch 50/500
# 6/6 [==============================] - 0s 15ms/step - loss: 0.4665 - accuracy: 0.6480 - val_loss: 0.5542 - val_accuracy: 0.6667
# Epoch 51/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.4615 - accuracy: 0.6480 - val_loss: 0.5561 - val_accuracy: 0.6667
# Epoch 52/500
# 6/6 [==============================] - 0s 16ms/step - loss: 0.4453 - accuracy: 0.6480 - val_loss: 0.5590 - val_accuracy: 0.6667
# Epoch 53/500
# 6/6 [==============================] - 0s 18ms/step - loss: 0.4442 - accuracy: 0.6480 - val_loss: 0.5620 - val_accuracy: 0.6667
# Epoch 54/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.4892 - accuracy: 0.6480 - val_loss: 0.5620 - val_accuracy: 0.6667
# Epoch 55/500
# 6/6 [==============================] - 0s 13ms/step - loss: 0.4943 - accuracy: 0.6480 - val_loss: 0.5613 - val_accuracy: 0.6667
# Epoch 56/500
# 6/6 [==============================] - 0s 16ms/step - loss: 0.4553 - accuracy: 0.6480 - val_loss: 0.5617 - val_accuracy: 0.6667
# Epoch 57/500
# 6/6 [==============================] - 0s 15ms/step - loss: 0.4552 - accuracy: 0.6480 - val_loss: 0.5644 - val_accuracy: 0.6667

# %%
val_accuracy = np.mean(history.history['val_accuracy']) # mean value of all epochs accuracy
print("\n%s: %.2f%%" % ('val_accuracy', val_accuracy*100))#print in percentage formation
# Out:
# val_accuracy: 66.67%

# %%
# Predicting the test set results
y_pred = model.predict(X_test) #predict with test data set
y_pred = (y_pred > 0.5) #make predicted value to 0 or 1:
y_pred
# Out:
# array([[False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False]])

# %%
y_test
# Out:
# 268    0
# 240    0
# 278    0
# 176    0
# 202    0
#       ..
# 24     1
# 62     0
# 249    0
# 90     0
# 50     1
# Name: DEATH_EVENT, Length: 75, dtype: int64

# %%
cf_matrix = confusion_matrix(y_test, y_pred) #compare y_test data and y_predict data and make a matrix
print(cf_matrix)
sns.heatmap(cf_matrix/np.sum(cf_matrix), annot = True) #show confusion matrix with accuracy rate of true and false predict
# Out:
# [[57  0]
#  [18  0]]
